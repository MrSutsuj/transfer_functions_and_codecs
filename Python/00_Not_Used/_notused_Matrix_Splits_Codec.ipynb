# %% [markdown]
# ### Codec Matrix Split

# %%
import sys
#sys.path.append('../shared/')
#import videodisko as vd
# Imports
import numpy as np
import numpy.matlib
import numpy.random

from mpl_toolkits.mplot3d import axes3d 

from matplotlib import pyplot as plt

from scipy import ndimage
from scipy import misc
from scipy import fftpack
from scipy import optimize
import scipy.io
import skimage
import imageio
import colour as c
import math
import csv

from ipywidgets import interact, interactive, fixed, interact_manual
import ipywidgets as widgets

import pandas as pd

import cv2
import time

from datetime import datetime

import os
from fnmatch import fnmatch

# %% [markdown]
# ## UHD Matrix

# %% [markdown]
# ### HDR PQ FR

# %%
root_path = "/Volumes/jm_HDD/jm_MA_V1/CONTENT/61_AUSWERTUNG/03.2_ARRI_Encounters_HLG_UHD_NR"
storage_path = "/Volumes/jm_HDD/jm_MA_V1/CONTENT/71_MATRIX_CODEC/03.2_ARRI_Encounters_HLG_UHD_NR"

for i in range(1,18):

    number = "{:04d}".format(i)

    pattern1_1 = "Co*"
    pattern1_2 = f"*V1-{number}*"
    pattern1_3 = "*JND.tif"

    pattern_ref = f"V1-{number}*"

    ### ProRes 4444
    target_folder_name1 = "01_Apple_ProRes_4444"

    for foldername, subfolders, filenames in os.walk(root_path):
        if target_folder_name1 in subfolders:
            folder_path = os.path.join(root_path, target_folder_name1)

            for path, subdirs, files in os.walk(folder_path):
                for name in files:
                    if fnmatch(name, pattern1_1):
                        if fnmatch(name, pattern1_2):
                            if fnmatch(name, pattern1_3):
                                print("ProRes 4444")
                                matrix_prores_4444 = c.read_image(os.path.join(path,name))

    ### ProRes 422 HQ
    target_folder_name2 = "02_Apple_ProRes_422_HQ"

    for foldername, subfolders, filenames in os.walk(root_path):
        if target_folder_name2 in subfolders:
            folder_path = os.path.join(root_path, target_folder_name2)

            for path, subdirs, files in os.walk(folder_path):
                for name in files:
                    if fnmatch(name, pattern1_1):
                        if fnmatch(name, pattern1_2):
                            if fnmatch(name, pattern1_3):
                                print("ProRes 422 HQ")
                                matrix_prores_422HQ = c.read_image(os.path.join(path,name))


    ### 03a_JPEG_2000_Profile_Level_1
    target_folder_name3 = "03a_JPEG_2000_Profile_Level_1"

    for foldername, subfolders, filenames in os.walk(root_path):
        if target_folder_name3 in subfolders:
            folder_path = os.path.join(root_path, target_folder_name3)

            for path, subdirs, files in os.walk(folder_path):
                for name in files:
                    if fnmatch(name, pattern1_1):
                        if fnmatch(name, pattern1_2):
                            if fnmatch(name, pattern1_3):
                                print("03a_JPEG_2000_Profile_Level_1")
                                matrix_JPEG_2000_Profile_Level_1 = c.read_image(os.path.join(path,name))


    ### 03b_JPEG_2000_Profile_Level_4
    target_folder_name4 = "03b_JPEG_2000_Profile_Level_4"

    for foldername, subfolders, filenames in os.walk(root_path):
        if target_folder_name4 in subfolders:
            folder_path = os.path.join(root_path, target_folder_name4)

            for path, subdirs, files in os.walk(folder_path):
                for name in files:
                    if fnmatch(name, pattern1_1):
                        if fnmatch(name, pattern1_2):
                            if fnmatch(name, pattern1_3):
                                print("03b_JPEG_2000_Profile_Level_4")
                                matrix_JPEG_2000_Profile_Level_4 = c.read_image(os.path.join(path,name))



    ### 04_Sony_XAVC-I_Class_300
    target_folder_name5 = "04_Sony_XAVC-I_Class_300"

    for foldername, subfolders, filenames in os.walk(root_path):
        if target_folder_name5 in subfolders:
            folder_path = os.path.join(root_path, target_folder_name5)

            for path, subdirs, files in os.walk(folder_path):
                for name in files:
                    if fnmatch(name, pattern1_1):
                        if fnmatch(name, pattern1_2):
                            if fnmatch(name, pattern1_3):
                                print("04_Sony_XAVC-I_Class_300")
                                matrix_Sony_XAVC_I_Class_300 = c.read_image(os.path.join(path,name))


    ### 05_Avid_DNxHR_444
    target_folder_name6 = "05_Avid_DNxHR_444"

    for foldername, subfolders, filenames in os.walk(root_path):
        if target_folder_name6 in subfolders:
            folder_path = os.path.join(root_path, target_folder_name6)

            for path, subdirs, files in os.walk(folder_path):
                for name in files:
                    if fnmatch(name, pattern1_1):
                        if fnmatch(name, pattern1_2):
                            if fnmatch(name, pattern1_3):
                                print("05_Avid_DNxHR_444")
                                matrix_Avid_DNxHR_444 = c.read_image(os.path.join(path,name))


    ### 06_Avid_DNxHR_HQX
    target_folder_name7= "06_Avid_DNxHR_HQX"

    for foldername, subfolders, filenames in os.walk(root_path):
        if target_folder_name7 in subfolders:
            folder_path = os.path.join(root_path, target_folder_name7)

            for path, subdirs, files in os.walk(folder_path):
                for name in files:
                    if fnmatch(name, pattern1_1):
                        if fnmatch(name, pattern1_2):
                            if fnmatch(name, pattern1_3):
                                print("06_Avid_DNxHR_HQX")
                                matrix_Avid_DNxHR_HQX = c.read_image(os.path.join(path,name))


    ### 07_Avid_DNxHD_220
    target_folder_name8 = "07_Avid_DNxHD_220"

    for foldername, subfolders, filenames in os.walk(root_path):
        if target_folder_name8 in subfolders:
            folder_path = os.path.join(root_path, target_folder_name8)

            for path, subdirs, files in os.walk(folder_path):
                for name in files:
                    if fnmatch(name, pattern1_1):
                        if fnmatch(name, pattern1_2):
                            if fnmatch(name, pattern1_3):
                                print("07_Avid_DNxHD_220")
                                matrix_Avid_DNxHD_220 = c.read_image(os.path.join(path,name))

    ### 08_Sony_XDCAM_HD220
    target_folder_name9 = "08_Sony_XDCAM_HD220"

    for foldername, subfolders, filenames in os.walk(root_path):
        if target_folder_name9 in subfolders:
            folder_path = os.path.join(root_path, target_folder_name9)

            for path, subdirs, files in os.walk(folder_path):
                for name in files:
                    if fnmatch(name, pattern1_1):
                        if fnmatch(name, pattern1_2):
                            if fnmatch(name, pattern1_3):
                                print("08_Sony_XDCAM_HD220")
                                matrix_Sony_XDCAM_HD220 = c.read_image(os.path.join(path,name))


    ### 09_H265_Main422_10
    target_folder_name10 = "09_H265_Main422_10"

    for foldername, subfolders, filenames in os.walk(root_path):
        if target_folder_name10 in subfolders:
            folder_path = os.path.join(root_path, target_folder_name10)

            for path, subdirs, files in os.walk(folder_path):
                for name in files:
                    if fnmatch(name, pattern1_1):
                        if fnmatch(name, pattern1_2):
                            if fnmatch(name, pattern1_3):
                                print("09_H265_Main422_10")
                                matrix_H265_Main422_10 = c.read_image(os.path.join(path,name))

    figA, ((ax1,ax2,ax3,ax4),(ax5,ax6,ax7,ax8)) = plt.subplots(2, 4, figsize=(30, 10))

    ax1.imshow(matrix_prores_4444[490:1220,150:1450,:])
    ax2.imshow(matrix_prores_422HQ[490:1220,150:1450,:])
    ax3.imshow(matrix_JPEG_2000_Profile_Level_1[490:1220,150:1450,:])
    ax4.imshow(matrix_JPEG_2000_Profile_Level_4[490:1220,150:1450,:])
    ax5.imshow(matrix_Sony_XAVC_I_Class_300[490:1220,150:1450,:])
    ax6.imshow(matrix_Avid_DNxHR_444[490:1220,150:1450,:])
    ax7.imshow(matrix_Avid_DNxHR_HQX[490:1220,150:1450,:])
    ax8.imshow(matrix_H265_Main422_10[490:1220,150:1450,:])

    ax1.spines['top'].set_visible(False)
    ax1.spines['right'].set_visible(False)
    ax1.spines['bottom'].set_visible(False)
    ax1.spines['left'].set_visible(False)
    ax1.get_xaxis().set_ticks([])
    ax1.get_yaxis().set_ticks([])

    ax2.spines['top'].set_visible(False)
    ax2.spines['right'].set_visible(False)
    ax2.spines['bottom'].set_visible(False)
    ax2.spines['left'].set_visible(False)
    ax2.get_xaxis().set_ticks([])
    ax2.get_yaxis().set_ticks([])

    ax3.spines['top'].set_visible(False)
    ax3.spines['right'].set_visible(False)
    ax3.spines['bottom'].set_visible(False)
    ax3.spines['left'].set_visible(False)
    ax3.get_xaxis().set_ticks([])
    ax3.get_yaxis().set_ticks([])

    ax4.spines['top'].set_visible(False)
    ax4.spines['right'].set_visible(False)
    ax4.spines['bottom'].set_visible(False)
    ax4.spines['left'].set_visible(False)
    ax4.get_xaxis().set_ticks([])
    ax4.get_yaxis().set_ticks([])

    ax5.spines['top'].set_visible(False)
    ax5.spines['right'].set_visible(False)
    ax5.spines['bottom'].set_visible(False)
    ax5.spines['left'].set_visible(False)
    ax5.get_xaxis().set_ticks([])
    ax5.get_yaxis().set_ticks([])

    ax6.spines['top'].set_visible(False)
    ax6.spines['right'].set_visible(False)
    ax6.spines['bottom'].set_visible(False)
    ax6.spines['left'].set_visible(False)
    ax6.get_xaxis().set_ticks([])
    ax6.get_yaxis().set_ticks([])

    ax7.spines['top'].set_visible(False)
    ax7.spines['right'].set_visible(False)
    ax7.spines['bottom'].set_visible(False)
    ax7.spines['left'].set_visible(False)
    ax7.get_xaxis().set_ticks([])
    ax7.get_yaxis().set_ticks([])

    ax8.spines['top'].set_visible(False)
    ax8.spines['right'].set_visible(False)
    ax8.spines['bottom'].set_visible(False)
    ax8.spines['left'].set_visible(False)
    ax8.get_xaxis().set_ticks([])
    ax8.get_yaxis().set_ticks([])

    ax1.set_title("01_Apple_ProRes_4444")
    ax2.set_title("02_Apple_ProRes_422_HQ")
    ax3.set_title("03a_JPEG_2000_Profile_Level_1")
    ax4.set_title("03b_JPEG_2000_Profile_Level_4")
    ax5.set_title("04_Sony_XAVC-I_Class_300")
    ax6.set_title("05_Avid_DNxHR_444")
    ax7.set_title("06_Avid_DNxHR_HQX")
    ax8.set_title("09_H265_Main422_10")

    figA.subplots_adjust(wspace=0.05, 
                        hspace=0.05)
    
    figA.savefig(storage_path + f"/Matrix_UHD_{number}.tif")

# %%
root_path = "/Volumes/jm_HDD/jm_MA_V1/CONTENT/61_AUSWERTUNG/04.2_ARRI_Encounters_HLG_HD_NR"
storage_path = "/Volumes/jm_HDD/jm_MA_V1/CONTENT/71_MATRIX_CODEC/04.2_ARRI_Encounters_HLG_HD_NR"

for i in range(1,18):

    number = "{:04d}".format(i)

    pattern1_1 = "Co*"
    pattern1_2 = f"*V1-{number}*"
    pattern1_3 = "*JND.tif"

    pattern_ref = f"V1-{number}*"

    ### ProRes 4444
    target_folder_name1 = "01_Apple_ProRes_4444"

    for foldername, subfolders, filenames in os.walk(root_path):
        if target_folder_name1 in subfolders:
            folder_path = os.path.join(root_path, target_folder_name1)

            for path, subdirs, files in os.walk(folder_path):
                for name in files:
                    if fnmatch(name, pattern1_1):
                        if fnmatch(name, pattern1_2):
                            if fnmatch(name, pattern1_3):
                                print("ProRes 4444")
                                matrix_prores_4444 = c.read_image(os.path.join(path,name))

    ### ProRes 422 HQ
    target_folder_name2 = "02_Apple_ProRes_422_HQ"

    for foldername, subfolders, filenames in os.walk(root_path):
        if target_folder_name2 in subfolders:
            folder_path = os.path.join(root_path, target_folder_name2)

            for path, subdirs, files in os.walk(folder_path):
                for name in files:
                    if fnmatch(name, pattern1_1):
                        if fnmatch(name, pattern1_2):
                            if fnmatch(name, pattern1_3):
                                print("ProRes 422 HQ")
                                matrix_prores_422HQ = c.read_image(os.path.join(path,name))


    ### 03a_JPEG_2000_Profile_Level_1
    target_folder_name3 = "03a_JPEG_2000_Profile_Level_1"

    for foldername, subfolders, filenames in os.walk(root_path):
        if target_folder_name3 in subfolders:
            folder_path = os.path.join(root_path, target_folder_name3)

            for path, subdirs, files in os.walk(folder_path):
                for name in files:
                    if fnmatch(name, pattern1_1):
                        if fnmatch(name, pattern1_2):
                            if fnmatch(name, pattern1_3):
                                print("03a_JPEG_2000_Profile_Level_1")
                                matrix_JPEG_2000_Profile_Level_1 = c.read_image(os.path.join(path,name))


    ### 03b_JPEG_2000_Profile_Level_4
    target_folder_name4 = "03b_JPEG_2000_Profile_Level_4"

    for foldername, subfolders, filenames in os.walk(root_path):
        if target_folder_name4 in subfolders:
            folder_path = os.path.join(root_path, target_folder_name4)

            for path, subdirs, files in os.walk(folder_path):
                for name in files:
                    if fnmatch(name, pattern1_1):
                        if fnmatch(name, pattern1_2):
                            if fnmatch(name, pattern1_3):
                                print("03b_JPEG_2000_Profile_Level_4")
                                matrix_JPEG_2000_Profile_Level_4 = c.read_image(os.path.join(path,name))



    ### 04_Sony_XAVC-I_Class_300
    target_folder_name5 = "04_Sony_XAVC-I_Class_300"

    for foldername, subfolders, filenames in os.walk(root_path):
        if target_folder_name5 in subfolders:
            folder_path = os.path.join(root_path, target_folder_name5)

            for path, subdirs, files in os.walk(folder_path):
                for name in files:
                    if fnmatch(name, pattern1_1):
                        if fnmatch(name, pattern1_2):
                            if fnmatch(name, pattern1_3):
                                print("04_Sony_XAVC-I_Class_300")
                                matrix_Sony_XAVC_I_Class_300 = c.read_image(os.path.join(path,name))


    ### 05_Avid_DNxHR_444
    target_folder_name6 = "05_Avid_DNxHR_444"

    for foldername, subfolders, filenames in os.walk(root_path):
        if target_folder_name6 in subfolders:
            folder_path = os.path.join(root_path, target_folder_name6)

            for path, subdirs, files in os.walk(folder_path):
                for name in files:
                    if fnmatch(name, pattern1_1):
                        if fnmatch(name, pattern1_2):
                            if fnmatch(name, pattern1_3):
                                print("05_Avid_DNxHR_444")
                                matrix_Avid_DNxHR_444 = c.read_image(os.path.join(path,name))


    ### 06_Avid_DNxHR_HQX
    target_folder_name7= "06_Avid_DNxHR_HQX"

    for foldername, subfolders, filenames in os.walk(root_path):
        if target_folder_name7 in subfolders:
            folder_path = os.path.join(root_path, target_folder_name7)

            for path, subdirs, files in os.walk(folder_path):
                for name in files:
                    if fnmatch(name, pattern1_1):
                        if fnmatch(name, pattern1_2):
                            if fnmatch(name, pattern1_3):
                                print("06_Avid_DNxHR_HQX")
                                matrix_Avid_DNxHR_HQX = c.read_image(os.path.join(path,name))


    ### 07_Avid_DNxHD_220
    target_folder_name8 = "07_Avid_DNxHD_220"

    for foldername, subfolders, filenames in os.walk(root_path):
        if target_folder_name8 in subfolders:
            folder_path = os.path.join(root_path, target_folder_name8)

            for path, subdirs, files in os.walk(folder_path):
                for name in files:
                    if fnmatch(name, pattern1_1):
                        if fnmatch(name, pattern1_2):
                            if fnmatch(name, pattern1_3):
                                print("07_Avid_DNxHD_220")
                                matrix_Avid_DNxHD_220 = c.read_image(os.path.join(path,name))

    ### 08_Sony_XDCAM_HD220
    target_folder_name9 = "08_Sony_XDCAM_HD220"

    for foldername, subfolders, filenames in os.walk(root_path):
        if target_folder_name9 in subfolders:
            folder_path = os.path.join(root_path, target_folder_name9)

            for path, subdirs, files in os.walk(folder_path):
                for name in files:
                    if fnmatch(name, pattern1_1):
                        if fnmatch(name, pattern1_2):
                            if fnmatch(name, pattern1_3):
                                print("08_Sony_XDCAM_HD220")
                                matrix_Sony_XDCAM_HD220 = c.read_image(os.path.join(path,name))


    ### 09_H265_Main422_10
    target_folder_name10 = "09_H265_Main422_10"

    for foldername, subfolders, filenames in os.walk(root_path):
        if target_folder_name10 in subfolders:
            folder_path = os.path.join(root_path, target_folder_name10)

            for path, subdirs, files in os.walk(folder_path):
                for name in files:
                    if fnmatch(name, pattern1_1):
                        if fnmatch(name, pattern1_2):
                            if fnmatch(name, pattern1_3):
                                print("09_H265_Main422_10")
                                matrix_H265_Main422_10 = c.read_image(os.path.join(path,name))

    figA, ((ax1,ax2,ax3),(ax4,ax5,ax6),(ax7,ax8,ax9)) = plt.subplots(3, 3, figsize=(30, 20))

    ax1.imshow(matrix_prores_4444[490:1220,150:1450,:])
    ax2.imshow(matrix_prores_422HQ[490:1220,150:1450,:])
    ax3.imshow(matrix_JPEG_2000_Profile_Level_1[490:1220,150:1450,:])
    ax4.imshow(matrix_JPEG_2000_Profile_Level_4[490:1220,150:1450,:])
    ax5.imshow(matrix_Avid_DNxHR_444[490:1220,150:1450,:])
    ax6.imshow(matrix_Avid_DNxHR_HQX[490:1220,150:1450,:])
    ax7.imshow(matrix_Avid_DNxHD_220[490:1220,150:1450,:])
    ax8.imshow(matrix_Sony_XDCAM_HD220[490:1220,150:1450,:])
    ax9.imshow(matrix_H265_Main422_10[490:1220,150:1450,:])

    ax1.spines['top'].set_visible(False)
    ax1.spines['right'].set_visible(False)
    ax1.spines['bottom'].set_visible(False)
    ax1.spines['left'].set_visible(False)
    ax1.get_xaxis().set_ticks([])
    ax1.get_yaxis().set_ticks([])

    ax2.spines['top'].set_visible(False)
    ax2.spines['right'].set_visible(False)
    ax2.spines['bottom'].set_visible(False)
    ax2.spines['left'].set_visible(False)
    ax2.get_xaxis().set_ticks([])
    ax2.get_yaxis().set_ticks([])

    ax3.spines['top'].set_visible(False)
    ax3.spines['right'].set_visible(False)
    ax3.spines['bottom'].set_visible(False)
    ax3.spines['left'].set_visible(False)
    ax3.get_xaxis().set_ticks([])
    ax3.get_yaxis().set_ticks([])

    ax4.spines['top'].set_visible(False)
    ax4.spines['right'].set_visible(False)
    ax4.spines['bottom'].set_visible(False)
    ax4.spines['left'].set_visible(False)
    ax4.get_xaxis().set_ticks([])
    ax4.get_yaxis().set_ticks([])

    ax5.spines['top'].set_visible(False)
    ax5.spines['right'].set_visible(False)
    ax5.spines['bottom'].set_visible(False)
    ax5.spines['left'].set_visible(False)
    ax5.get_xaxis().set_ticks([])
    ax5.get_yaxis().set_ticks([])

    ax6.spines['top'].set_visible(False)
    ax6.spines['right'].set_visible(False)
    ax6.spines['bottom'].set_visible(False)
    ax6.spines['left'].set_visible(False)
    ax6.get_xaxis().set_ticks([])
    ax6.get_yaxis().set_ticks([])

    ax7.spines['top'].set_visible(False)
    ax7.spines['right'].set_visible(False)
    ax7.spines['bottom'].set_visible(False)
    ax7.spines['left'].set_visible(False)
    ax7.get_xaxis().set_ticks([])
    ax7.get_yaxis().set_ticks([])

    ax8.spines['top'].set_visible(False)
    ax8.spines['right'].set_visible(False)
    ax8.spines['bottom'].set_visible(False)
    ax8.spines['left'].set_visible(False)
    ax8.get_xaxis().set_ticks([])
    ax8.get_yaxis().set_ticks([])

    ax9.spines['top'].set_visible(False)
    ax9.spines['right'].set_visible(False)
    ax9.spines['bottom'].set_visible(False)
    ax9.spines['left'].set_visible(False)
    ax9.get_xaxis().set_ticks([])
    ax9.get_yaxis().set_ticks([])

    ax1.set_title("01_Apple_ProRes_4444")
    ax2.set_title("02_Apple_ProRes_422_HQ")
    ax3.set_title("03a_JPEG_2000_Profile_Level_1")
    ax4.set_title("03b_JPEG_2000_Profile_Level_4")
    ax5.set_title("05_Avid_DNxHR_444")
    ax6.set_title("06_Avid_DNxHR_HQX")
    ax7.set_title("07_Avid_DNxHD_220")
    ax8.set_title("08_Sony_XDCAM_HD220")
    ax9.set_title("09_H265_Main422_10")

    figA.subplots_adjust(wspace=0.05, 
                        hspace=0.05)

    figA.savefig(storage_path + f"/Matrix_HD_{number}.tif")

# %%
root_path = "/Volumes/jm_HDD/jm_MA_V1/CONTENT/61.1_AUSWERTUNG_MATLAB/01.2_ARRI_Encounters_PQ_UHD_NR"
storage_path = "/Volumes/jm_HDD/jm_MA_V1/CONTENT/71.1_MATRIX_CODEC_MATLAB/01.2_ARRI_Encounters_PQ_UHD_NR"

for i in range(1,18):

    number = "{:04d}".format(i)

    pattern1_1 = "Co*"
    pattern1_2 = f"*V1-{number}*"
    pattern1_3 = "*MATLAB.tif"

    pattern_ref = f"V1-{number}*"

    ### ProRes 4444
    target_folder_name1 = "01_Apple_ProRes_4444"

    for foldername, subfolders, filenames in os.walk(root_path):
        if target_folder_name1 in subfolders:
            folder_path = os.path.join(root_path, target_folder_name1)

            for path, subdirs, files in os.walk(folder_path):
                for name in files:
                    if fnmatch(name, pattern1_1):
                        if fnmatch(name, pattern1_2):
                            if fnmatch(name, pattern1_3):
                                print("ProRes 4444")
                                matrix_prores_4444 = c.read_image(os.path.join(path,name))

    ### ProRes 422 HQ
    target_folder_name2 = "02_Apple_ProRes_422_HQ"

    for foldername, subfolders, filenames in os.walk(root_path):
        if target_folder_name2 in subfolders:
            folder_path = os.path.join(root_path, target_folder_name2)

            for path, subdirs, files in os.walk(folder_path):
                for name in files:
                    if fnmatch(name, pattern1_1):
                        if fnmatch(name, pattern1_2):
                            if fnmatch(name, pattern1_3):
                                print("ProRes 422 HQ")
                                matrix_prores_422HQ = c.read_image(os.path.join(path,name))


    ### 03a_JPEG_2000_Profile_Level_1
    target_folder_name3 = "03a_JPEG_2000_Profile_Level_1"

    for foldername, subfolders, filenames in os.walk(root_path):
        if target_folder_name3 in subfolders:
            folder_path = os.path.join(root_path, target_folder_name3)

            for path, subdirs, files in os.walk(folder_path):
                for name in files:
                    if fnmatch(name, pattern1_1):
                        if fnmatch(name, pattern1_2):
                            if fnmatch(name, pattern1_3):
                                print("03a_JPEG_2000_Profile_Level_1")
                                matrix_JPEG_2000_Profile_Level_1 = c.read_image(os.path.join(path,name))


    ### 03b_JPEG_2000_Profile_Level_4
    target_folder_name4 = "03b_JPEG_2000_Profile_Level_4"

    for foldername, subfolders, filenames in os.walk(root_path):
        if target_folder_name4 in subfolders:
            folder_path = os.path.join(root_path, target_folder_name4)

            for path, subdirs, files in os.walk(folder_path):
                for name in files:
                    if fnmatch(name, pattern1_1):
                        if fnmatch(name, pattern1_2):
                            if fnmatch(name, pattern1_3):
                                print("03b_JPEG_2000_Profile_Level_4")
                                matrix_JPEG_2000_Profile_Level_4 = c.read_image(os.path.join(path,name))



    ### 04_Sony_XAVC-I_Class_300
    target_folder_name5 = "04_Sony_XAVC-I_Class_300"

    for foldername, subfolders, filenames in os.walk(root_path):
        if target_folder_name5 in subfolders:
            folder_path = os.path.join(root_path, target_folder_name5)

            for path, subdirs, files in os.walk(folder_path):
                for name in files:
                    if fnmatch(name, pattern1_1):
                        if fnmatch(name, pattern1_2):
                            if fnmatch(name, pattern1_3):
                                print("04_Sony_XAVC-I_Class_300")
                                matrix_Sony_XAVC_I_Class_300 = c.read_image(os.path.join(path,name))


    ### 05_Avid_DNxHR_444
    target_folder_name6 = "05_Avid_DNxHR_444"

    for foldername, subfolders, filenames in os.walk(root_path):
        if target_folder_name6 in subfolders:
            folder_path = os.path.join(root_path, target_folder_name6)

            for path, subdirs, files in os.walk(folder_path):
                for name in files:
                    if fnmatch(name, pattern1_1):
                        if fnmatch(name, pattern1_2):
                            if fnmatch(name, pattern1_3):
                                print("05_Avid_DNxHR_444")
                                matrix_Avid_DNxHR_444 = c.read_image(os.path.join(path,name))


    ### 06_Avid_DNxHR_HQX
    target_folder_name7= "06_Avid_DNxHR_HQX"

    for foldername, subfolders, filenames in os.walk(root_path):
        if target_folder_name7 in subfolders:
            folder_path = os.path.join(root_path, target_folder_name7)

            for path, subdirs, files in os.walk(folder_path):
                for name in files:
                    if fnmatch(name, pattern1_1):
                        if fnmatch(name, pattern1_2):
                            if fnmatch(name, pattern1_3):
                                print("06_Avid_DNxHR_HQX")
                                matrix_Avid_DNxHR_HQX = c.read_image(os.path.join(path,name))


    ### 07_Avid_DNxHD_220
    target_folder_name8 = "07_Avid_DNxHD_220"

    for foldername, subfolders, filenames in os.walk(root_path):
        if target_folder_name8 in subfolders:
            folder_path = os.path.join(root_path, target_folder_name8)

            for path, subdirs, files in os.walk(folder_path):
                for name in files:
                    if fnmatch(name, pattern1_1):
                        if fnmatch(name, pattern1_2):
                            if fnmatch(name, pattern1_3):
                                print("07_Avid_DNxHD_220")
                                matrix_Avid_DNxHD_220 = c.read_image(os.path.join(path,name))

    ### 08_Sony_XDCAM_HD220
    target_folder_name9 = "08_Sony_XDCAM_HD220"

    for foldername, subfolders, filenames in os.walk(root_path):
        if target_folder_name9 in subfolders:
            folder_path = os.path.join(root_path, target_folder_name9)

            for path, subdirs, files in os.walk(folder_path):
                for name in files:
                    if fnmatch(name, pattern1_1):
                        if fnmatch(name, pattern1_2):
                            if fnmatch(name, pattern1_3):
                                print("08_Sony_XDCAM_HD220")
                                matrix_Sony_XDCAM_HD220 = c.read_image(os.path.join(path,name))


    ### 09_H265_Main422_10
    target_folder_name10 = "09_H265_Main422_10"

    for foldername, subfolders, filenames in os.walk(root_path):
        if target_folder_name10 in subfolders:
            folder_path = os.path.join(root_path, target_folder_name10)

            for path, subdirs, files in os.walk(folder_path):
                for name in files:
                    if fnmatch(name, pattern1_1):
                        if fnmatch(name, pattern1_2):
                            if fnmatch(name, pattern1_3):
                                print("09_H265_Main422_10")
                                matrix_H265_Main422_10 = c.read_image(os.path.join(path,name))

    figA, ((ax1,ax2,ax3,ax4),(ax5,ax6,ax7,ax8)) = plt.subplots(2, 4, figsize=(30, 10))

    ax1.imshow(matrix_prores_4444)
    ax2.imshow(matrix_prores_422HQ)
    ax3.imshow(matrix_JPEG_2000_Profile_Level_1)
    ax4.imshow(matrix_JPEG_2000_Profile_Level_4)
    ax5.imshow(matrix_Sony_XAVC_I_Class_300)
    ax6.imshow(matrix_Avid_DNxHR_444)
    ax7.imshow(matrix_Avid_DNxHR_HQX)
    ax8.imshow(matrix_H265_Main422_10)

    ax1.spines['top'].set_visible(False)
    ax1.spines['right'].set_visible(False)
    ax1.spines['bottom'].set_visible(False)
    ax1.spines['left'].set_visible(False)
    ax1.get_xaxis().set_ticks([])
    ax1.get_yaxis().set_ticks([])

    ax2.spines['top'].set_visible(False)
    ax2.spines['right'].set_visible(False)
    ax2.spines['bottom'].set_visible(False)
    ax2.spines['left'].set_visible(False)
    ax2.get_xaxis().set_ticks([])
    ax2.get_yaxis().set_ticks([])

    ax3.spines['top'].set_visible(False)
    ax3.spines['right'].set_visible(False)
    ax3.spines['bottom'].set_visible(False)
    ax3.spines['left'].set_visible(False)
    ax3.get_xaxis().set_ticks([])
    ax3.get_yaxis().set_ticks([])

    ax4.spines['top'].set_visible(False)
    ax4.spines['right'].set_visible(False)
    ax4.spines['bottom'].set_visible(False)
    ax4.spines['left'].set_visible(False)
    ax4.get_xaxis().set_ticks([])
    ax4.get_yaxis().set_ticks([])

    ax5.spines['top'].set_visible(False)
    ax5.spines['right'].set_visible(False)
    ax5.spines['bottom'].set_visible(False)
    ax5.spines['left'].set_visible(False)
    ax5.get_xaxis().set_ticks([])
    ax5.get_yaxis().set_ticks([])

    ax6.spines['top'].set_visible(False)
    ax6.spines['right'].set_visible(False)
    ax6.spines['bottom'].set_visible(False)
    ax6.spines['left'].set_visible(False)
    ax6.get_xaxis().set_ticks([])
    ax6.get_yaxis().set_ticks([])

    ax7.spines['top'].set_visible(False)
    ax7.spines['right'].set_visible(False)
    ax7.spines['bottom'].set_visible(False)
    ax7.spines['left'].set_visible(False)
    ax7.get_xaxis().set_ticks([])
    ax7.get_yaxis().set_ticks([])

    ax8.spines['top'].set_visible(False)
    ax8.spines['right'].set_visible(False)
    ax8.spines['bottom'].set_visible(False)
    ax8.spines['left'].set_visible(False)
    ax8.get_xaxis().set_ticks([])
    ax8.get_yaxis().set_ticks([])

    ax1.set_title("01_Apple_ProRes_4444")
    ax2.set_title("02_Apple_ProRes_422_HQ")
    ax3.set_title("03a_JPEG_2000_Profile_Level_1")
    ax4.set_title("03b_JPEG_2000_Profile_Level_4")
    ax5.set_title("04_Sony_XAVC-I_Class_300")
    ax6.set_title("05_Avid_DNxHR_444")
    ax7.set_title("06_Avid_DNxHR_HQX")
    ax8.set_title("09_H265_Main422_10")

    figA.subplots_adjust(wspace=0.05, 
                        hspace=0.05)
    
    figA.savefig(storage_path + f"/Matrix_UHD_{number}.tif")

# %%
root_path = "/Volumes/jm_HDD/jm_MA_V1/CONTENT/61.1_AUSWERTUNG_MATLAB/02.2_ARRI_Encounters_PQ_HD_NR"
storage_path = "/Volumes/jm_HDD/jm_MA_V1/CONTENT/71.1_MATRIX_CODEC_MATLAB/02.2_ARRI_Encounters_PQ_HD_NR"

for i in range(1,18):

    number = "{:04d}".format(i)

    pattern1_1 = "Co*"
    pattern1_2 = f"*V1-{number}*"
    pattern1_3 = "*MATLAB.tif"

    pattern_ref = f"V1-{number}*"

    ### ProRes 4444
    target_folder_name1 = "01_Apple_ProRes_4444"

    for foldername, subfolders, filenames in os.walk(root_path):
        if target_folder_name1 in subfolders:
            folder_path = os.path.join(root_path, target_folder_name1)

            for path, subdirs, files in os.walk(folder_path):
                for name in files:
                    if fnmatch(name, pattern1_1):
                        if fnmatch(name, pattern1_2):
                            if fnmatch(name, pattern1_3):
                                print("ProRes 4444")
                                matrix_prores_4444 = c.read_image(os.path.join(path,name))

    ### ProRes 422 HQ
    target_folder_name2 = "02_Apple_ProRes_422_HQ"

    for foldername, subfolders, filenames in os.walk(root_path):
        if target_folder_name2 in subfolders:
            folder_path = os.path.join(root_path, target_folder_name2)

            for path, subdirs, files in os.walk(folder_path):
                for name in files:
                    if fnmatch(name, pattern1_1):
                        if fnmatch(name, pattern1_2):
                            if fnmatch(name, pattern1_3):
                                print("ProRes 422 HQ")
                                matrix_prores_422HQ = c.read_image(os.path.join(path,name))


    ### 03a_JPEG_2000_Profile_Level_1
    target_folder_name3 = "03a_JPEG_2000_Profile_Level_1"

    for foldername, subfolders, filenames in os.walk(root_path):
        if target_folder_name3 in subfolders:
            folder_path = os.path.join(root_path, target_folder_name3)

            for path, subdirs, files in os.walk(folder_path):
                for name in files:
                    if fnmatch(name, pattern1_1):
                        if fnmatch(name, pattern1_2):
                            if fnmatch(name, pattern1_3):
                                print("03a_JPEG_2000_Profile_Level_1")
                                matrix_JPEG_2000_Profile_Level_1 = c.read_image(os.path.join(path,name))


    ### 03b_JPEG_2000_Profile_Level_4
    target_folder_name4 = "03b_JPEG_2000_Profile_Level_4"

    for foldername, subfolders, filenames in os.walk(root_path):
        if target_folder_name4 in subfolders:
            folder_path = os.path.join(root_path, target_folder_name4)

            for path, subdirs, files in os.walk(folder_path):
                for name in files:
                    if fnmatch(name, pattern1_1):
                        if fnmatch(name, pattern1_2):
                            if fnmatch(name, pattern1_3):
                                print("03b_JPEG_2000_Profile_Level_4")
                                matrix_JPEG_2000_Profile_Level_4 = c.read_image(os.path.join(path,name))



    ### 04_Sony_XAVC-I_Class_300
    target_folder_name5 = "04_Sony_XAVC-I_Class_300"

    for foldername, subfolders, filenames in os.walk(root_path):
        if target_folder_name5 in subfolders:
            folder_path = os.path.join(root_path, target_folder_name5)

            for path, subdirs, files in os.walk(folder_path):
                for name in files:
                    if fnmatch(name, pattern1_1):
                        if fnmatch(name, pattern1_2):
                            if fnmatch(name, pattern1_3):
                                print("04_Sony_XAVC-I_Class_300")
                                matrix_Sony_XAVC_I_Class_300 = c.read_image(os.path.join(path,name))


    ### 05_Avid_DNxHR_444
    target_folder_name6 = "05_Avid_DNxHR_444"

    for foldername, subfolders, filenames in os.walk(root_path):
        if target_folder_name6 in subfolders:
            folder_path = os.path.join(root_path, target_folder_name6)

            for path, subdirs, files in os.walk(folder_path):
                for name in files:
                    if fnmatch(name, pattern1_1):
                        if fnmatch(name, pattern1_2):
                            if fnmatch(name, pattern1_3):
                                print("05_Avid_DNxHR_444")
                                matrix_Avid_DNxHR_444 = c.read_image(os.path.join(path,name))


    ### 06_Avid_DNxHR_HQX
    target_folder_name7= "06_Avid_DNxHR_HQX"

    for foldername, subfolders, filenames in os.walk(root_path):
        if target_folder_name7 in subfolders:
            folder_path = os.path.join(root_path, target_folder_name7)

            for path, subdirs, files in os.walk(folder_path):
                for name in files:
                    if fnmatch(name, pattern1_1):
                        if fnmatch(name, pattern1_2):
                            if fnmatch(name, pattern1_3):
                                print("06_Avid_DNxHR_HQX")
                                matrix_Avid_DNxHR_HQX = c.read_image(os.path.join(path,name))


    ### 07_Avid_DNxHD_220
    target_folder_name8 = "07_Avid_DNxHD_220"

    for foldername, subfolders, filenames in os.walk(root_path):
        if target_folder_name8 in subfolders:
            folder_path = os.path.join(root_path, target_folder_name8)

            for path, subdirs, files in os.walk(folder_path):
                for name in files:
                    if fnmatch(name, pattern1_1):
                        if fnmatch(name, pattern1_2):
                            if fnmatch(name, pattern1_3):
                                print("07_Avid_DNxHD_220")
                                matrix_Avid_DNxHD_220 = c.read_image(os.path.join(path,name))

    ### 08_Sony_XDCAM_HD220
    target_folder_name9 = "08_Sony_XDCAM_HD220"

    for foldername, subfolders, filenames in os.walk(root_path):
        if target_folder_name9 in subfolders:
            folder_path = os.path.join(root_path, target_folder_name9)

            for path, subdirs, files in os.walk(folder_path):
                for name in files:
                    if fnmatch(name, pattern1_1):
                        if fnmatch(name, pattern1_2):
                            if fnmatch(name, pattern1_3):
                                print("08_Sony_XDCAM_HD220")
                                matrix_Sony_XDCAM_HD220 = c.read_image(os.path.join(path,name))


    ### 09_H265_Main422_10
    target_folder_name10 = "09_H265_Main422_10"

    for foldername, subfolders, filenames in os.walk(root_path):
        if target_folder_name10 in subfolders:
            folder_path = os.path.join(root_path, target_folder_name10)

            for path, subdirs, files in os.walk(folder_path):
                for name in files:
                    if fnmatch(name, pattern1_1):
                        if fnmatch(name, pattern1_2):
                            if fnmatch(name, pattern1_3):
                                print("09_H265_Main422_10")
                                matrix_H265_Main422_10 = c.read_image(os.path.join(path,name))

    figA, ((ax1,ax2,ax3),(ax4,ax5,ax6),(ax7,ax8,ax9)) = plt.subplots(3, 3, figsize=(30, 20))

    ax1.imshow(matrix_prores_4444)
    ax2.imshow(matrix_prores_422HQ)
    ax3.imshow(matrix_JPEG_2000_Profile_Level_1)
    ax4.imshow(matrix_JPEG_2000_Profile_Level_4)
    ax5.imshow(matrix_Avid_DNxHR_444)
    ax6.imshow(matrix_Avid_DNxHR_HQX)
    ax7.imshow(matrix_Avid_DNxHD_220)
    ax8.imshow(matrix_Sony_XDCAM_HD220)
    ax9.imshow(matrix_H265_Main422_10)

    ax1.spines['top'].set_visible(False)
    ax1.spines['right'].set_visible(False)
    ax1.spines['bottom'].set_visible(False)
    ax1.spines['left'].set_visible(False)
    ax1.get_xaxis().set_ticks([])
    ax1.get_yaxis().set_ticks([])

    ax2.spines['top'].set_visible(False)
    ax2.spines['right'].set_visible(False)
    ax2.spines['bottom'].set_visible(False)
    ax2.spines['left'].set_visible(False)
    ax2.get_xaxis().set_ticks([])
    ax2.get_yaxis().set_ticks([])

    ax3.spines['top'].set_visible(False)
    ax3.spines['right'].set_visible(False)
    ax3.spines['bottom'].set_visible(False)
    ax3.spines['left'].set_visible(False)
    ax3.get_xaxis().set_ticks([])
    ax3.get_yaxis().set_ticks([])

    ax4.spines['top'].set_visible(False)
    ax4.spines['right'].set_visible(False)
    ax4.spines['bottom'].set_visible(False)
    ax4.spines['left'].set_visible(False)
    ax4.get_xaxis().set_ticks([])
    ax4.get_yaxis().set_ticks([])

    ax5.spines['top'].set_visible(False)
    ax5.spines['right'].set_visible(False)
    ax5.spines['bottom'].set_visible(False)
    ax5.spines['left'].set_visible(False)
    ax5.get_xaxis().set_ticks([])
    ax5.get_yaxis().set_ticks([])

    ax6.spines['top'].set_visible(False)
    ax6.spines['right'].set_visible(False)
    ax6.spines['bottom'].set_visible(False)
    ax6.spines['left'].set_visible(False)
    ax6.get_xaxis().set_ticks([])
    ax6.get_yaxis().set_ticks([])

    ax7.spines['top'].set_visible(False)
    ax7.spines['right'].set_visible(False)
    ax7.spines['bottom'].set_visible(False)
    ax7.spines['left'].set_visible(False)
    ax7.get_xaxis().set_ticks([])
    ax7.get_yaxis().set_ticks([])

    ax8.spines['top'].set_visible(False)
    ax8.spines['right'].set_visible(False)
    ax8.spines['bottom'].set_visible(False)
    ax8.spines['left'].set_visible(False)
    ax8.get_xaxis().set_ticks([])
    ax8.get_yaxis().set_ticks([])

    ax9.spines['top'].set_visible(False)
    ax9.spines['right'].set_visible(False)
    ax9.spines['bottom'].set_visible(False)
    ax9.spines['left'].set_visible(False)
    ax9.get_xaxis().set_ticks([])
    ax9.get_yaxis().set_ticks([])

    ax1.set_title("01_Apple_ProRes_4444")
    ax2.set_title("02_Apple_ProRes_422_HQ")
    ax3.set_title("03a_JPEG_2000_Profile_Level_1")
    ax4.set_title("03b_JPEG_2000_Profile_Level_4")
    ax5.set_title("05_Avid_DNxHR_444")
    ax6.set_title("06_Avid_DNxHR_HQX")
    ax7.set_title("07_Avid_DNxHD_220")
    ax8.set_title("08_Sony_XDCAM_HD220")
    ax9.set_title("09_H265_Main422_10")

    figA.subplots_adjust(wspace=0.05, 
                        hspace=0.05)

    figA.savefig(storage_path + f"/Matrix_HD_{number}.tif")
