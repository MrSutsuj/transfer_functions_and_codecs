# %% [markdown]
# ### Delete Files without Pattern

# %%
import sys
import numpy as np
import numpy.matlib
import numpy.random
import ipywidgets as widgets
import scipy.io
import skimage
import imageio
import colour as c
import math
import csv
import ipywidgets as widgets
import cv2
import time
import re
import pandas as pd
import numpy as np
import os
import heapq

from mpl_toolkits.mplot3d import axes3d 
from matplotlib import pyplot as plt
from matplotlib.patches import Rectangle
from ipywidgets import interact, interactive, fixed, interact_manual
from scipy import ndimage
from scipy import misc
from scipy import fftpack
from scipy import optimize
from datetime import datetime
from matplotlib.patches import Rectangle
from fnmatch import fnmatch
from matplotlib.colors import ListedColormap
from matplotlib.colors import ListedColormap
from matplotlib.colors import LinearSegmentedColormap

# %%
ref_root = "/Volumes/Extreme SSD/01.1_ARRI_Encounters_PQ_UHD_FR"
# ref_root = "/Volumes/Extreme SSD/01.2_ARRI_Encounters_PQ_UHD_NR"
# ref_root = "/Volumes/Extreme SSD/02.1_ARRI_Encounters_PQ_HD_FR"
# ref_root = "/Volumes/Extreme SSD/02.2_ARRI_Encounters_PQ_HD_NR"
# ref_root = "/Volumes/Extreme SSD/03.1_ARRI_Encounters_HLG_UHD_FR"
# ref_root = "/Volumes/Extreme SSD/03.2_ARRI_Encounters_HLG_UHD_NR"
# ref_root = "/Volumes/Extreme SSD/04.1_ARRI_Encounters_HLG_HD_FR"
# ref_root = "/Volumes/Extreme SSD/04.2_ARRI_Encounters_HLG_HD_NR"

pattern1 = f"*000200.tif"
pattern2 = f"*Comp*"

for path, subdirs, files in os.walk(ref_root):
        for name in files:
            if fnmatch(name, pattern1):
                print("Dich behalt ich")
            elif fnmatch(name, pattern2):
                del_path = os.path.join(path,name)
                os.remove(del_path)
                print("Du wirst gelöscht")

# %%
# ref_root = "/Volumes/Extreme SSD/01.1_ARRI_Encounters_PQ_UHD_FR"
ref_root = "/Volumes/Extreme SSD/01.2_ARRI_Encounters_PQ_UHD_NR"
# ref_root = "/Volumes/Extreme SSD/02.1_ARRI_Encounters_PQ_HD_FR"
# ref_root = "/Volumes/Extreme SSD/02.2_ARRI_Encounters_PQ_HD_NR"
# ref_root = "/Volumes/Extreme SSD/03.1_ARRI_Encounters_HLG_UHD_FR"
# ref_root = "/Volumes/Extreme SSD/03.2_ARRI_Encounters_HLG_UHD_NR"
# ref_root = "/Volumes/Extreme SSD/04.1_ARRI_Encounters_HLG_HD_FR"
# ref_root = "/Volumes/Extreme SSD/04.2_ARRI_Encounters_HLG_HD_NR"

pattern1 = f"*000200.tif"
pattern2 = f"*Comp*"

for path, subdirs, files in os.walk(ref_root):
        for name in files:
            if fnmatch(name, pattern1):
                print("Dich behalt ich")
            elif fnmatch(name, pattern2):
                del_path = os.path.join(path,name)
                os.remove(del_path)
                print("Du wirst gelöscht")

# %%
# ref_root = "/Volumes/Extreme SSD/01.1_ARRI_Encounters_PQ_UHD_FR"
# ref_root = "/Volumes/Extreme SSD/01.2_ARRI_Encounters_PQ_UHD_NR"
ref_root = "/Volumes/Extreme SSD/02.1_ARRI_Encounters_PQ_HD_FR"
# ref_root = "/Volumes/Extreme SSD/02.2_ARRI_Encounters_PQ_HD_NR"
# ref_root = "/Volumes/Extreme SSD/03.1_ARRI_Encounters_HLG_UHD_FR"
# ref_root = "/Volumes/Extreme SSD/03.2_ARRI_Encounters_HLG_UHD_NR"
# ref_root = "/Volumes/Extreme SSD/04.1_ARRI_Encounters_HLG_HD_FR"
# ref_root = "/Volumes/Extreme SSD/04.2_ARRI_Encounters_HLG_HD_NR"

pattern1 = f"*000200.tif"
pattern2 = f"*Comp*"

for path, subdirs, files in os.walk(ref_root):
        for name in files:
            if fnmatch(name, pattern1):
                print("Dich behalt ich")
            elif fnmatch(name, pattern2):
                del_path = os.path.join(path,name)
                os.remove(del_path)
                print("Du wirst gelöscht")

# %%
# ref_root = "/Volumes/Extreme SSD/01.1_ARRI_Encounters_PQ_UHD_FR"
# ref_root = "/Volumes/Extreme SSD/01.2_ARRI_Encounters_PQ_UHD_NR"
# ref_root = "/Volumes/Extreme SSD/02.1_ARRI_Encounters_PQ_HD_FR"
ref_root = "/Volumes/Extreme SSD/02.2_ARRI_Encounters_PQ_HD_NR"
# ref_root = "/Volumes/Extreme SSD/03.1_ARRI_Encounters_HLG_UHD_FR"
# ref_root = "/Volumes/Extreme SSD/03.2_ARRI_Encounters_HLG_UHD_NR"
# ref_root = "/Volumes/Extreme SSD/04.1_ARRI_Encounters_HLG_HD_FR"
# ref_root = "/Volumes/Extreme SSD/04.2_ARRI_Encounters_HLG_HD_NR"

pattern1 = f"*000200.tif"
pattern2 = f"*Comp*"

for path, subdirs, files in os.walk(ref_root):
        for name in files:
            if fnmatch(name, pattern1):
                print("Dich behalt ich")
            elif fnmatch(name, pattern2):
                del_path = os.path.join(path,name)
                os.remove(del_path)
                print("Du wirst gelöscht")

# %%
# ref_root = "/Volumes/Extreme SSD/01.1_ARRI_Encounters_PQ_UHD_FR"
# ref_root = "/Volumes/Extreme SSD/01.2_ARRI_Encounters_PQ_UHD_NR"
# ref_root = "/Volumes/Extreme SSD/02.1_ARRI_Encounters_PQ_HD_FR"
# ref_root = "/Volumes/Extreme SSD/02.2_ARRI_Encounters_PQ_HD_NR"
ref_root = "/Volumes/Extreme SSD/03.1_ARRI_Encounters_HLG_UHD_FR"
# ref_root = "/Volumes/Extreme SSD/03.2_ARRI_Encounters_HLG_UHD_NR"
# ref_root = "/Volumes/Extreme SSD/04.1_ARRI_Encounters_HLG_HD_FR"
# ref_root = "/Volumes/Extreme SSD/04.2_ARRI_Encounters_HLG_HD_NR"

pattern1 = f"*000200.tif"
pattern2 = f"*Comp*"

for path, subdirs, files in os.walk(ref_root):
        for name in files:
            if fnmatch(name, pattern1):
                print("Dich behalt ich")
            elif fnmatch(name, pattern2):
                del_path = os.path.join(path,name)
                os.remove(del_path)
                print("Du wirst gelöscht")

# %%
# ref_root = "/Volumes/Extreme SSD/01.1_ARRI_Encounters_PQ_UHD_FR"
# ref_root = "/Volumes/Extreme SSD/01.2_ARRI_Encounters_PQ_UHD_NR"
# ref_root = "/Volumes/Extreme SSD/02.1_ARRI_Encounters_PQ_HD_FR"
# ref_root = "/Volumes/Extreme SSD/02.2_ARRI_Encounters_PQ_HD_NR"
# ref_root = "/Volumes/Extreme SSD/03.1_ARRI_Encounters_HLG_UHD_FR"
ref_root = "/Volumes/Extreme SSD/03.2_ARRI_Encounters_HLG_UHD_NR"
# ref_root = "/Volumes/Extreme SSD/04.1_ARRI_Encounters_HLG_HD_FR"
# ref_root = "/Volumes/Extreme SSD/04.2_ARRI_Encounters_HLG_HD_NR"

pattern1 = f"*000200.tif"
pattern2 = f"*Comp*"

for path, subdirs, files in os.walk(ref_root):
        for name in files:
            if fnmatch(name, pattern1):
                print("Dich behalt ich")
            elif fnmatch(name, pattern2):
                del_path = os.path.join(path,name)
                os.remove(del_path)
                print("Du wirst gelöscht")

# %%
# ref_root = "/Volumes/Extreme SSD/01.1_ARRI_Encounters_PQ_UHD_FR"
# ref_root = "/Volumes/Extreme SSD/01.2_ARRI_Encounters_PQ_UHD_NR"
# ref_root = "/Volumes/Extreme SSD/02.1_ARRI_Encounters_PQ_HD_FR"
# ref_root = "/Volumes/Extreme SSD/02.2_ARRI_Encounters_PQ_HD_NR"
# ref_root = "/Volumes/Extreme SSD/03.1_ARRI_Encounters_HLG_UHD_FR"
# ref_root = "/Volumes/Extreme SSD/03.2_ARRI_Encounters_HLG_UHD_NR"
ref_root = "/Volumes/Extreme SSD/04.1_ARRI_Encounters_HLG_HD_FR"
# ref_root = "/Volumes/Extreme SSD/04.2_ARRI_Encounters_HLG_HD_NR"

pattern1 = f"*000200.tif"
pattern2 = f"*Comp*"

for path, subdirs, files in os.walk(ref_root):
        for name in files:
            if fnmatch(name, pattern1):
                print("Dich behalt ich")
            elif fnmatch(name, pattern2):
                del_path = os.path.join(path,name)
                os.remove(del_path)
                print("Du wirst gelöscht")

# %%
# ref_root = "/Volumes/Extreme SSD/01.1_ARRI_Encounters_PQ_UHD_FR"
# ref_root = "/Volumes/Extreme SSD/01.2_ARRI_Encounters_PQ_UHD_NR"
# ref_root = "/Volumes/Extreme SSD/02.1_ARRI_Encounters_PQ_HD_FR"
# ref_root = "/Volumes/Extreme SSD/02.2_ARRI_Encounters_PQ_HD_NR"
# ref_root = "/Volumes/Extreme SSD/03.1_ARRI_Encounters_HLG_UHD_FR"
# ref_root = "/Volumes/Extreme SSD/03.2_ARRI_Encounters_HLG_UHD_NR"
# ref_root = "/Volumes/Extreme SSD/04.1_ARRI_Encounters_HLG_HD_FR"
ref_root = "/Volumes/Extreme SSD/04.2_ARRI_Encounters_HLG_HD_NR"

pattern1 = f"*000200.tif"
pattern2 = f"*Comp*"

for path, subdirs, files in os.walk(ref_root):
        for name in files:
            if fnmatch(name, pattern1):
                print("Dich behalt ich")
            elif fnmatch(name, pattern2):
                del_path = os.path.join(path,name)
                os.remove(del_path)
                print("Du wirst gelöscht")
